# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# # Training Linear Regression model

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Training Polynomial Regression

# %% [markdown]
# ## Training with a degree of 2

# %%
from sklearn .preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Visualization

# %% [markdown]
# ## For Linear Regression

# %%
plt.figure(figsize = (12,6))
plt.scatter(X,y,color='orange')
plt.plot(X,lin_reg.predict(X), color='green')

# %% [markdown]
# # With polynomial Regression

# %%
plt.figure(figsize = (12,6))
plt.scatter(X,y,color='orange')
plt.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)), color='green')

# %% [markdown]
# ## Training with a degree of 3

# %%
from sklearn .preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 3)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.figure(figsize = (12,6))
plt.scatter(X,y,color='orange')
plt.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)), color='green')

# %% [markdown]
# ## Training with a degree of 4

# %%
from sklearn .preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.figure(figsize = (12,6))
plt.scatter(X,y,color='orange')
plt.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)), color='green')

# %% [markdown]
# ## Predicting

# %% [markdown]
# ### Predicting with Linear Regression

# %%
lin_reg.predict([[5.5]])
# Out:
# array([249500.])

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
lin_reg.predict([[7.5]])
# Out:
# array([411257.57575758])

# %% [markdown]
# ## Predicitng with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[5.5]]))
# Out:
# array([132148.43750003])

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])

# %%
lin_reg_2.predict(poly_reg.fit_transform([[7.5]]))
# Out:
# array([225126.29297787])
